# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#        id                                title  \
# 0     238                        The Godfather
# 1     278             The Shawshank Redemption
# 2  569094  Spider-Man: Across the Spider-Verse
# 3     240                The Godfather Part II
# 4     424                     Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     129.513
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     117.398
# 2  After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31    2096.296
# 3  In the continuing saga of the Corleone crime f...   1974-12-20      67.228
# 4  The true story of how businessman Oskar Schind...   1993-12-15      62.706
#
#    vote_average  vote_count
# 0           8.7       18113
# 1           8.7       23988
# 2           8.7        1588
# 3           8.6       10934
# 4           8.6       14186

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                                              title  \
# 0        238                                      The Godfather
# 1        278                           The Shawshank Redemption
# 2     569094                Spider-Man: Across the Spider-Verse
# 3        240                              The Godfather Part II
# 4        424                                   Schindler's List
# ...      ...                                                ...
# 8555  254194                                        Starry Eyes
# 8556   28302  The Swan Princess: The Mystery of the Enchante...
# 8557   39345                                 Casper Meets Wendy
# 8558   34583                                          The Final
# 8559   10555                                         Shark Tale
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...                                                 ...          ...
# 8555  A hopeful young starlet uncovers the ominous o...   2014-07-29
# 8556  The royal couple Odette and Derek face yet ano...   1998-08-04
# 8557  When a warlock threatens Wendy the Good Little...   1998-09-08
# 8558  A group of high school outcasts get revenge on...   2010-01-28
# 8559  Oscar is a small fish whose big aspirations of...   2004-09-20
#
#       popularity  vote_average  vote_count
# 0        129.513           8.7       18113
# 1        117.398           8.7       23988
# 2       2096.296           8.7        1588
# 3         67.228           8.6       10934
# 4         62.706           8.6       14186
# ...          ...           ...         ...
# 8555       7.899           6.0         393
# 8556      12.800           6.0         229
# 8557      10.358           6.0         350
# 8558      13.360           6.0         236
# 8559      51.406           6.0        5811
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
